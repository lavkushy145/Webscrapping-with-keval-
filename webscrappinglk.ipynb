# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq
import logging
import numpy as np
import time

# %%
flipcart_link = "https://www.flipkart.com/search?q="+input()

# %%
flipcart_link
# Out:
# 'https://www.flipkart.com/search?q=iphone'

# %%
urlclient = uReq(flipcart_link)

# %%
urlclient

# %%
flipcart_page=urlclient.read()

# %%
flipcart_html=bs(flipcart_page,'html.parser')

# %%
flipcart_html
# Out:
# <!DOCTYPE html>
# ...

# %%
bigbox=flipcart_html.findAll("div",{"class":"_1AtVbE col-12-12"})

# %%
bigbox
# Out:
# [<div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=iphone&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles/pr?sid=tyy,4
# ...

# %%
size = len(bigbox)
print(size)
# Out:
# 30

# %%
del(bigbox[:2],bigbox[25:])

# %%
size = len(bigbox)
print(size)
# Out:
# 25

# %%
url = []
for i in range(0,size-4):
    product_link="https://www.flipkart.com" + bigbox[i].div.a['href']
    url.append(product_link)
print(url)
# Out:
# ['https://www.flipkart.com/apple-iphone-14-purple-128-gb/p/itm0b581eba85e08?pid=MOBGHWFHQFSQYBFU&lid=LSTMOBGHWFHQFSQYBFU9AP8AR&marketplace=FLIPKART&q=iphone&store=tyy%2F4io&spotlightTagId=BestsellerId_tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=fc79f655-eb89-4245-bd8f-a0f56c0ed13b.MOBGHWFHQFSQYBFU.SEARCH&ppt=None&ppn=None&ssid=ep633sbp4w0000001680843888906&qH=0b3f45b266a97d70', 'https://www.flipkart.com/apple-iphone-14-starlight-128-gb/p/itm3485a56f6e676?pid=MOBGHWFHABH3G73H&lid=LSTMOBGHWFHABH3G73HVXY5AV&marketplace=FLIPKART&q=iphone&store=tyy%2F4io&spotlightTagId=BestsellerId_tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=fc79f655-eb89-4245-bd8f-a0f56c0ed13b.MOBGHWFHABH3G73H.SEARCH&ppt=None&ppn=None&ssid=ep633sbp4w0000001680843888906&qH=0b3f45b266a97d70', 'https://www.flipkart.com/apple-iphone-14-midnight-128-gb/p/itm9e6293c322a84?pid=MOBGHWFHECFVMDCX&lid=LSTMOBGHWFHECFVMDCXBOYSND&marketplace=FLIPKART&q=iphone&store=tyy%2F4io&spotlightTagId=FkPickId_tyy%2F4io&srno=s_1_3
# ...

# %%
metaData = []
templs = []
for i in url:
    product_req = requests.get(i)
    product_html = bs(product_req.text,'html.parser')
    title=product_html.find("span",{"class":"B_NuCI"})
    rate=product_html.find_all("div",{"class":"_2d4LTz"})
    numOfRate=product_html.find_all("div",{"class":"row _2afbiS"})
    price=product_html.find_all("div",{"class":"_30jeq3 _16Jk6d"})
    #Title---------------------------->
    textTitle = f'{title}'
    soup = bs(textTitle, 'html.parser')
    textTitle = soup.get_text()
    textTitle = textTitle.replace('[', '').replace(']', '')
    #Rate------------------------------>
    textRate = f'{rate}'
    soup = bs(textRate, 'html.parser')
    textRate = soup.get_text()
    textRate = textRate.replace('[', '').replace(']', '')
    #Comment--------------------------->
    textNOR = f'{numOfRate}'
    soup = bs(textNOR, 'html.parser')
    textNOR = soup.get_text()
    textNOR = textNOR.replace('[', '').replace(']', '')
    #Name------------------------------>
    textPrice = f'{price}'
    soup = bs(textPrice, 'html.parser')
    textPrice = soup.get_text()
    textPrice = textPrice.replace('[', '').replace(']', '')
    #<----------------------------------------------------------------->
    metaData.append(i)
    metaData.append(textTitle)
    metaData.append(textPrice)
    metaData.append(textRate)
    metaData.append(textNOR)

# %%
metaData
# Out:
# ['https://www.flipkart.com/apple-iphone-14-purple-128-gb/p/itm0b581eba85e08?pid=MOBGHWFHQFSQYBFU&lid=LSTMOBGHWFHQFSQYBFU9AP8AR&marketplace=FLIPKART&q=iphone&store=tyy%2F4io&spotlightTagId=BestsellerId_tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=fc79f655-eb89-4245-bd8f-a0f56c0ed13b.MOBGHWFHQFSQYBFU.SEARCH&ppt=None&ppn=None&ssid=ep633sbp4w0000001680843888906&qH=0b3f45b266a97d70',
#  'APPLE iPhone 14 (Purple, 128 GB)',
#  '₹71,999',
#  '4.6',
#  '26,869 Ratings &, 1,056 Reviews',
#  'https://www.flipkart.com/apple-iphone-14-starlight-128-gb/p/itm3485a56f6e676?pid=MOBGHWFHABH3G73H&lid=LSTMOBGHWFHABH3G73HVXY5AV&marketplace=FLIPKART&q=iphone&store=tyy%2F4io&spotlightTagId=BestsellerId_tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=fc79f655-eb89-4245-bd8f-a0f56c0ed13b.MOBGHWFHABH3G73H.SEARCH&ppt=None&ppn=None&ssid=ep633sbp4w0000001680843888906&qH=0b3f45b266a97d70',
#  'APPLE iPhone 14 (Starlight, 128 GB)',
#  '₹71,999',
#  '4.6',
#  '26,869 Ratings &, 1,056 Reviews',
# ...

# %%
from openpyxl import Workbook
workbook = Workbook()
worksheet = workbook.active
def csvFile(name, price, rate, buyers ,url, numRow):
    worksheet.cell(row= numRow, column=1, value= name)
    worksheet.cell(row= numRow, column=2, value= price)
    worksheet.cell(row= numRow, column=3, value= rate)
    worksheet.cell(row= numRow, column=4, value= buyers)
    worksheet.cell(row= numRow, column=5, value= url)
    workbook.save('datax.xlsx')

# %%
i = 0
row = 1
while i <= 100:
    link = metaData[i]
    textTitle = metaData[i+1]
    price = metaData[i+2]
    rating = metaData[i+3]
    buyers = metaData[i+4]
    csvFile(textTitle,price,rating,buyers,link, row)
    row += 1
    i += 5
